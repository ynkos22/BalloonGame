# %% [markdown]
# # AI Agents
#
# *Andrew Wang · 2026-08-08*

# %% [markdown]
# ## Contents
#
# 1. [Introduction](#introduction)
# 2. [Problem Formulation](#problem-formulation)
# 3. [Training](#training)
# 4. [Evaluation](#evaluation)
# 5. [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction

# %% [markdown]
# After writing detailed enough description of the game that achieves the following goals
# 1. Clear description of _all_ the game dynamics
# 2. Make sure the AI is trying its very best
#
# we fed it to Claude Fable 5.1 and told it to not use its memory. Specifically, here it the prompt we used:

# %% [markdown]
# "Do not use any of your memory when answering this prompt. Follow this game description and try your best in developing an optimal strategy. Once you're ready code it out under my strategies in strategies.py."

# %% [markdown]
# This is what it came up with compared to $0$-greedy:

# %%
import os
import sys
MODULES_DIR = os.path.abspath(os.path.join(os.getcwd(), "..", "..", "modules"))
if MODULES_DIR not in sys.path:
    sys.path.insert(0, MODULES_DIR)

from plotting import plot_PnL_curves, plot_regret_curves
plot_PnL_curves("eps_greedy_vs_Claude_1000")
plot_regret_curves("eps_greedy_vs_Claude_1000")

# %% [markdown]
# There are multiple important points to be made from this plot.
#
# 1. Noise is starting to matter, so we should look for ways to reduce it
# 2. It is performing significantly better than $0$-greedy, and hence showing we _can_ do better.
# 3. It is performing asymptotically better than $0$-greedy.

# %% [markdown]
# ## Problem Formulation

# %% [markdown]
# ## Training

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ## Conclusion
